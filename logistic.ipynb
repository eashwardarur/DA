# %% [markdown]
# <a href="https://colab.research.google.com/github/eashwardarur/DA/blob/main/logistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
d=load_diabetes()

# %%
df=pd.DataFrame(d.data,columns=d.feature_names)

# %%
df['target']=d.target

# %%
out=[]
for i in df['target']:
  if i>=140:
    out.append(1)
  else:
    out.append(0)
out

# %%
df['out']=out

# %%
df=df.drop(['target'],axis=1)

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,df['out'],test_size=0.2,random_state=42)

# %%
logmodel=LogisticRegression()
logmodel.fit(Xtrain,ytrain)

# %%
ypred=logmodel.predict(Xtest)
ypred
